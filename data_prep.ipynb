# %%
import pandas as pd
import seaborn as sns
import env
import acquire
import matplotlib.pyplot as plt
import seaborn as sns

# %%
store_data = acquire.get_store_data()
store_data
# Out:
#         store_id  item_id   item_upc14   item_upc12 item_brand  \
# 0              1        1  35200264013  35200264013   Riceland
# 1              1        1  35200264013  35200264013   Riceland
# 2              1        1  35200264013  35200264013   Riceland
# 3              1        1  35200264013  35200264013   Riceland
# 4              1        1  35200264013  35200264013   Riceland
# ...          ...      ...          ...          ...        ...
# 764189         9       19  41520035646  41520035646    Careone
# 764190         9       19  41520035646  41520035646    Careone
# 764191         9       19  41520035646  41520035646    Careone
# 764192         9       19  41520035646  41520035646    Careone
# 764193         9       19  41520035646  41520035646    Careone
#
#                              item_name  item_price  sale_id   sale_date  \
# 0       Riceland American Jazmine Rice        0.84        1  2013-01-01
# 1       Riceland American Jazmine Rice        0.84        2  2013-01-02
# 2       Riceland American Jazmine Rice        0.84        3  2013-01-03
# 3       Riceland American Jazmine Rice        0.84        4  2013-01-04
# 4       Riceland American Jazmine Rice        0.84        5  2013-01-05
# ...                                ...         ...      ...         ...
# 764189  Careone Family Comb Set - 8 Ct        0.74   344210  2015-07-11
# 764190  Careone Family Comb Set - 8 Ct        0.74   344211  2015-07-12
# 764191  Careone Family Comb Set - 8 Ct        0.74   344212  2015-07-13
# 764192  Careone Family Comb Set - 8 Ct        0.74   344213  2015-07-14
# 764193  Careone Family Comb Set - 8 Ct        0.74   344214  2015-07-15
#
#         sale_amount           store_address  store_zipcode   store_city  \
# 0                13  12125 Alamo Ranch Pkwy          78253  San Antonio
# 1                11  12125 Alamo Ranch Pkwy          78253  San Antonio
# 2                14  12125 Alamo Ranch Pkwy          78253  San Antonio
# 3                13  12125 Alamo Ranch Pkwy          78253  San Antonio
# 4                10  12125 Alamo Ranch Pkwy          78253  San Antonio
# ...             ...                     ...            ...          ...
# 764189           53      735 SW Military Dr          78221  San Antonio
# 764190           80      735 SW Military Dr          78221  San Antonio
# 764191           40      735 SW Military Dr          78221  San Antonio
# 764192           44      735 SW Military Dr          78221  San Antonio
# 764193           56      735 SW Military Dr          78221  San Antonio
#
#        store_state
# 0               TX
# 1               TX
# 2               TX
# 3               TX
# 4               TX
# ...            ...
# 764189          TX
# 764190          TX
# 764191          TX
# 764192          TX
# 764193          TX
#
# [764194 rows x 14 columns]

# %%
store_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 764194 entries, 0 to 764193
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   store_id       764194 non-null  int64
#  1   item_id        764194 non-null  int64
#  2   item_upc14     764194 non-null  int64
#  3   item_upc12     764194 non-null  int64
#  4   item_brand     764194 non-null  object
#  5   item_name      764194 non-null  object
#  6   item_price     764194 non-null  float64
#  7   sale_id        764194 non-null  int64
#  8   sale_date      764194 non-null  object
#  9   sale_amount    764194 non-null  int64
#  10  store_address  764194 non-null  object
#  11  store_zipcode  764194 non-null  int64
#  12  store_city     764194 non-null  object
#  13  store_state    764194 non-null  object
# dtypes: float64(1), int64(7), object(6)
# memory usage: 87.5+ MB

# %% [markdown]
# Using your store items data:
#
# Convert date column to datetime format.

# %%
store_data.sale_date = pd.to_datetime(store_data.sale_date)

# %%
store_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 764194 entries, 0 to 764193
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   store_id       764194 non-null  int64
#  1   item_id        764194 non-null  int64
#  2   item_upc14     764194 non-null  int64
#  3   item_upc12     764194 non-null  int64
#  4   item_brand     764194 non-null  object
#  5   item_name      764194 non-null  object
#  6   item_price     764194 non-null  float64
#  7   sale_id        764194 non-null  int64
#  8   sale_date      764194 non-null  datetime64[ns]
#  9   sale_amount    764194 non-null  int64
#  10  store_address  764194 non-null  object
#  11  store_zipcode  764194 non-null  int64
#  12  store_city     764194 non-null  object
#  13  store_state    764194 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(7), object(5)
# memory usage: 87.5+ MB

# %% [markdown]
# Plot the distribution of sale_amount and item_price.

# %%
# by_date = df.groupby(['sale_date']).sale_amount.sum().reset_index()
# by_date.plot(x='sale_date', y='sale_amount')

# %%
by_date = store_data.groupby(['sale_date']).sale_amount.sum()
by_date.plot(x='sale_date', y='sale_amount')
# Out:
# <Axes: xlabel='sale_date'>

# %%
by_price = store_data.groupby(['sale_date']).item_price
by_price.plot(x='sale_date', y='item_price')
# Out:
# sale_date
# 2013-01-01    Axes(0.125,0.11;0.775x0.77)
# 2013-01-02    Axes(0.125,0.11;0.775x0.77)
# 2013-01-03    Axes(0.125,0.11;0.775x0.77)
# 2013-01-04    Axes(0.125,0.11;0.775x0.77)
# 2013-01-05    Axes(0.125,0.11;0.775x0.77)
#                          ...
# 2017-12-27    Axes(0.125,0.11;0.775x0.77)
# 2017-12-28    Axes(0.125,0.11;0.775x0.77)
# 2017-12-29    Axes(0.125,0.11;0.775x0.77)
# 2017-12-30    Axes(0.125,0.11;0.775x0.77)
# 2017-12-31    Axes(0.125,0.11;0.775x0.77)
# Name: item_price, Length: 1826, dtype: object

# %% [markdown]
# Set the index to be the datetime variable.

# %%
store_data = store_data.set_index('sale_date').sort_index()

# %%
store_data
# Out:
#             store_id  item_id    item_upc14    item_upc12  \
# sale_date
# 2013-01-01         1        1   35200264013   35200264013
# 2013-01-01         7       41   31000670016   31000670016
# 2013-01-01         3       18   21200725340   21200725340
# 2013-01-01         5       48   79400271631   79400271631
# 2013-01-01         5       47  884623708976  884623708976
# ...              ...      ...           ...           ...
# 2017-12-31         9       13  603084234561  603084234561
# 2017-12-31         7        2   11111065925   11111065925
# 2017-12-31         7        3   23923330139   23923330139
# 2017-12-31         4       17   88313590791   88313590791
# 2017-12-31         7        9   19600923015   19600923015
#
#                        item_brand  \
# sale_date
# 2013-01-01               Riceland
# 2013-01-01            P.f. Changs
# 2013-01-01                 Scotch
# 2013-01-01                   Dove
# 2013-01-01             Bear Naked
# ...                           ...
# 2017-12-31  Garnier Nutritioniste
# 2017-12-31                 Caress
# 2017-12-31            Earths Best
# 2017-12-31                  Ducal
# 2017-12-31           Van De Kamps
#
#                                                     item_name  item_price  \
# sale_date
# 2013-01-01                     Riceland American Jazmine Rice        0.84
# 2013-01-01  P.f. Changs Home Menu Meal For Two Beef With B...        5.62
# 2013-01-01    Scotch Removable Clear Mounting Squares - 35 Ct        4.39
# 2013-01-01  Dove Men + Care Antiperspirant Deodorant Cool ...        3.72
# 2013-01-01  Bear Naked Fit Almond Crisp 100 Percent Natura...        7.38
# ...                                                       ...         ...
# 2017-12-31  Garnier Nutritioniste Moisture Rescue Fresh Cl...        6.47
# 2017-12-31  Caress Velvet Bliss Ultra Silkening Beauty Bar...        6.44
# 2017-12-31  Earths Best Organic Fruit Yogurt Smoothie Mixe...        2.43
# 2017-12-31                            Ducal Refried Red Beans        1.16
# 2017-12-31         Van De Kamps Fillets Beer Battered - 10 Ct        1.79
#
#             sale_id  sale_amount            store_address  store_zipcode  \
# sale_date
# 2013-01-01        1           13   12125 Alamo Ranch Pkwy          78253
# 2013-01-01   741357            8   12018 Perrin Beitel Rd          78217
# 2013-01-01   314073           45  2118 Fredericksburg Rdj          78201
# 2013-01-01   865525           21          1520 Austin Hwy          78218
# 2013-01-01   847265            9          1520 Austin Hwy          78218
# ...             ...          ...                      ...            ...
# 2017-12-31   235554           89       735 SW Military Dr          78221
# 2017-12-31    31042           39   12018 Perrin Beitel Rd          78217
# 2017-12-31    49302           31   12018 Perrin Beitel Rd          78217
# 2017-12-31   299464           26          516 S Flores St          78204
# 2017-12-31   158862           38   12018 Perrin Beitel Rd          78217
#
#              store_city store_state
# sale_date
# 2013-01-01  San Antonio          TX
# 2013-01-01  San Antonio          TX
# 2013-01-01  San Antonio          TX
# 2013-01-01  San Antonio          TX
# 2013-01-01  San Antonio          TX
# ...                 ...         ...
# 2017-12-31  San Antonio          TX
# 2017-12-31  San Antonio          TX
# 2017-12-31  San Antonio          TX
# 2017-12-31  San Antonio          TX
# 2017-12-31  San Antonio          TX
#
# [764194 rows x 13 columns]

# %% [markdown]
# Add a 'month' and 'day of week' column to your dataframe.

# %%
store_data['month'] = store_data.index.month
store_data['day of week'] = store_data.index.day_name()
store_data
# Out:
#             store_id  item_id    item_upc14    item_upc12  \
# sale_date
# 2013-01-01         1        1   35200264013   35200264013
# 2013-01-01         7       41   31000670016   31000670016
# 2013-01-01         3       18   21200725340   21200725340
# 2013-01-01         5       48   79400271631   79400271631
# 2013-01-01         5       47  884623708976  884623708976
# ...              ...      ...           ...           ...
# 2017-12-31         9       13  603084234561  603084234561
# 2017-12-31         7        2   11111065925   11111065925
# 2017-12-31         7        3   23923330139   23923330139
# 2017-12-31         4       17   88313590791   88313590791
# 2017-12-31         7        9   19600923015   19600923015
#
#                        item_brand  \
# sale_date
# 2013-01-01               Riceland
# 2013-01-01            P.f. Changs
# 2013-01-01                 Scotch
# 2013-01-01                   Dove
# 2013-01-01             Bear Naked
# ...                           ...
# 2017-12-31  Garnier Nutritioniste
# 2017-12-31                 Caress
# 2017-12-31            Earths Best
# 2017-12-31                  Ducal
# 2017-12-31           Van De Kamps
#
#                                                     item_name  item_price  \
# sale_date
# 2013-01-01                     Riceland American Jazmine Rice        0.84
# 2013-01-01  P.f. Changs Home Menu Meal For Two Beef With B...        5.62
# 2013-01-01    Scotch Removable Clear Mounting Squares - 35 Ct        4.39
# 2013-01-01  Dove Men + Care Antiperspirant Deodorant Cool ...        3.72
# 2013-01-01  Bear Naked Fit Almond Crisp 100 Percent Natura...        7.38
# ...                                                       ...         ...
# 2017-12-31  Garnier Nutritioniste Moisture Rescue Fresh Cl...        6.47
# 2017-12-31  Caress Velvet Bliss Ultra Silkening Beauty Bar...        6.44
# 2017-12-31  Earths Best Organic Fruit Yogurt Smoothie Mixe...        2.43
# 2017-12-31                            Ducal Refried Red Beans        1.16
# 2017-12-31         Van De Kamps Fillets Beer Battered - 10 Ct        1.79
#
#             sale_id  sale_amount            store_address  store_zipcode  \
# sale_date
# 2013-01-01        1           13   12125 Alamo Ranch Pkwy          78253
# 2013-01-01   741357            8   12018 Perrin Beitel Rd          78217
# 2013-01-01   314073           45  2118 Fredericksburg Rdj          78201
# 2013-01-01   865525           21          1520 Austin Hwy          78218
# 2013-01-01   847265            9          1520 Austin Hwy          78218
# ...             ...          ...                      ...            ...
# 2017-12-31   235554           89       735 SW Military Dr          78221
# 2017-12-31    31042           39   12018 Perrin Beitel Rd          78217
# 2017-12-31    49302           31   12018 Perrin Beitel Rd          78217
# 2017-12-31   299464           26          516 S Flores St          78204
# 2017-12-31   158862           38   12018 Perrin Beitel Rd          78217
#
#              store_city store_state  month day of week
# sale_date
# 2013-01-01  San Antonio          TX      1     Tuesday
# 2013-01-01  San Antonio          TX      1     Tuesday
# 2013-01-01  San Antonio          TX      1     Tuesday
# 2013-01-01  San Antonio          TX      1     Tuesday
# 2013-01-01  San Antonio          TX      1     Tuesday
# ...                 ...         ...    ...         ...
# 2017-12-31  San Antonio          TX     12      Sunday
# 2017-12-31  San Antonio          TX     12      Sunday
# 2017-12-31  San Antonio          TX     12      Sunday
# 2017-12-31  San Antonio          TX     12      Sunday
# 2017-12-31  San Antonio          TX     12      Sunday
#
# [764194 rows x 15 columns]

# %% [markdown]
# Add a column to your dataframe, sales_total, which is a derived from sale_amount (total items) and item_price.

# %%
store_data['sales_total'] = store_data.sale_amount * store_data.item_price
store_data
# Out:
#             store_id  item_id    item_upc14    item_upc12  \
# sale_date
# 2013-01-01         1        1   35200264013   35200264013
# 2013-01-01         7       41   31000670016   31000670016
# 2013-01-01         3       18   21200725340   21200725340
# 2013-01-01         5       48   79400271631   79400271631
# 2013-01-01         5       47  884623708976  884623708976
# ...              ...      ...           ...           ...
# 2017-12-31         9       13  603084234561  603084234561
# 2017-12-31         7        2   11111065925   11111065925
# 2017-12-31         7        3   23923330139   23923330139
# 2017-12-31         4       17   88313590791   88313590791
# 2017-12-31         7        9   19600923015   19600923015
#
#                        item_brand  \
# sale_date
# 2013-01-01               Riceland
# 2013-01-01            P.f. Changs
# 2013-01-01                 Scotch
# 2013-01-01                   Dove
# 2013-01-01             Bear Naked
# ...                           ...
# 2017-12-31  Garnier Nutritioniste
# 2017-12-31                 Caress
# 2017-12-31            Earths Best
# 2017-12-31                  Ducal
# 2017-12-31           Van De Kamps
#
#                                                     item_name  item_price  \
# sale_date
# 2013-01-01                     Riceland American Jazmine Rice        0.84
# 2013-01-01  P.f. Changs Home Menu Meal For Two Beef With B...        5.62
# 2013-01-01    Scotch Removable Clear Mounting Squares - 35 Ct        4.39
# 2013-01-01  Dove Men + Care Antiperspirant Deodorant Cool ...        3.72
# 2013-01-01  Bear Naked Fit Almond Crisp 100 Percent Natura...        7.38
# ...                                                       ...         ...
# 2017-12-31  Garnier Nutritioniste Moisture Rescue Fresh Cl...        6.47
# 2017-12-31  Caress Velvet Bliss Ultra Silkening Beauty Bar...        6.44
# 2017-12-31  Earths Best Organic Fruit Yogurt Smoothie Mixe...        2.43
# 2017-12-31                            Ducal Refried Red Beans        1.16
# 2017-12-31         Van De Kamps Fillets Beer Battered - 10 Ct        1.79
#
#             sale_id  sale_amount            store_address  store_zipcode  \
# sale_date
# 2013-01-01        1           13   12125 Alamo Ranch Pkwy          78253
# 2013-01-01   741357            8   12018 Perrin Beitel Rd          78217
# 2013-01-01   314073           45  2118 Fredericksburg Rdj          78201
# 2013-01-01   865525           21          1520 Austin Hwy          78218
# 2013-01-01   847265            9          1520 Austin Hwy          78218
# ...             ...          ...                      ...            ...
# 2017-12-31   235554           89       735 SW Military Dr          78221
# 2017-12-31    31042           39   12018 Perrin Beitel Rd          78217
# 2017-12-31    49302           31   12018 Perrin Beitel Rd          78217
# 2017-12-31   299464           26          516 S Flores St          78204
# 2017-12-31   158862           38   12018 Perrin Beitel Rd          78217
#
#              store_city store_state  month day of week  sales_total
# sale_date
# 2013-01-01  San Antonio          TX      1     Tuesday        10.92
# 2013-01-01  San Antonio          TX      1     Tuesday        44.96
# 2013-01-01  San Antonio          TX      1     Tuesday       197.55
# 2013-01-01  San Antonio          TX      1     Tuesday        78.12
# 2013-01-01  San Antonio          TX      1     Tuesday        66.42
# ...                 ...         ...    ...         ...          ...
# 2017-12-31  San Antonio          TX     12      Sunday       575.83
# 2017-12-31  San Antonio          TX     12      Sunday       251.16
# 2017-12-31  San Antonio          TX     12      Sunday        75.33
# 2017-12-31  San Antonio          TX     12      Sunday        30.16
# 2017-12-31  San Antonio          TX     12      Sunday        68.02
#
# [764194 rows x 16 columns]

# %% [markdown]
# Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %% [markdown]
# Using the OPS data acquired in the Acquire exercises opsd_germany_daily.csv, complete the following:

# %%
opsd_germany = pd.read_csv('https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv')

# %%
opsd_germany.Date = pd.to_datetime(opsd_germany.Date)

# %% [markdown]
# Convert date column to datetime format.

# %%
opsd_germany.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4383 entries, 0 to 4382
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         4383 non-null   datetime64[ns]
#  1   Consumption  4383 non-null   float64
#  2   Wind         2920 non-null   float64
#  3   Solar        2188 non-null   float64
#  4   Wind+Solar   2187 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 171.3 KB

# %%
opsd_germany
# Out:
#            Date  Consumption     Wind   Solar  Wind+Solar
# 0    2006-01-01   1069.18400      NaN     NaN         NaN
# 1    2006-01-02   1380.52100      NaN     NaN         NaN
# 2    2006-01-03   1442.53300      NaN     NaN         NaN
# 3    2006-01-04   1457.21700      NaN     NaN         NaN
# 4    2006-01-05   1477.13100      NaN     NaN         NaN
# ...         ...          ...      ...     ...         ...
# 4378 2017-12-27   1263.94091  394.507  16.530     411.037
# 4379 2017-12-28   1299.86398  506.424  14.162     520.586
# 4380 2017-12-29   1295.08753  584.277  29.854     614.131
# 4381 2017-12-30   1215.44897  721.247   7.467     728.714
# 4382 2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 5 columns]

# %% [markdown]
# Plot the distribution of each of your variables.

# %%
for col in opsd_germany.columns:
    print(col)
    plt.hist(opsd_germany[col])
    plt.show()
# Out:
# Date
# Consumption
# Wind
# Solar
# Wind+Solar

# %% [markdown]
# Set the index to be the datetime variable.

# %%
opsd_germany = opsd_germany.set_index('Date').sort_index()

# %% [markdown]
# Add a month and a year column to your dataframe.

# %%
opsd_germany['month'] = opsd_germany.index.month
opsd_germany['year'] = opsd_germany.index.year
opsd_germany.iloc[2100:2200]
# Out:
#             Consumption     Wind   Solar  Wind+Solar  month  year
# Date
# 2011-10-02     1039.455   14.676     NaN         NaN     10  2011
# 2011-10-03     1061.849   95.156     NaN         NaN     10  2011
# 2011-10-04     1389.196  144.634     NaN         NaN     10  2011
# 2011-10-05     1423.514  157.136     NaN         NaN     10  2011
# 2011-10-06     1437.352  296.835     NaN         NaN     10  2011
# ...                 ...      ...     ...         ...    ...   ...
# 2012-01-05     1376.658  523.851   5.071     528.922      1  2012
# 2012-01-06     1291.215  286.265  13.160     299.425      1  2012
# 2012-01-07     1175.688  368.288   4.115     372.403      1  2012
# 2012-01-08     1103.383  220.851   8.440     229.291      1  2012
# 2012-01-09     1443.371  151.837   5.264     157.101      1  2012
#
# [100 rows x 6 columns]

# %%
Fill any missing values.

# %%
opsd_germany.isna().sum()
# Out:
# Consumption       0
# Wind           1463
# Solar          2195
# Wind+Solar     2196
# month             0
# year              0
# dtype: int64

# %%
opsd_germany.fillna(0, inplace=True)

# %%
opsd_germany
# Out:
#             Consumption     Wind   Solar  Wind+Solar  month  year
# Date
# 2006-01-01   1069.18400    0.000   0.000       0.000      1  2006
# 2006-01-02   1380.52100    0.000   0.000       0.000      1  2006
# 2006-01-03   1442.53300    0.000   0.000       0.000      1  2006
# 2006-01-04   1457.21700    0.000   0.000       0.000      1  2006
# 2006-01-05   1477.13100    0.000   0.000       0.000      1  2006
# ...                 ...      ...     ...         ...    ...   ...
# 2017-12-27   1263.94091  394.507  16.530     411.037     12  2017
# 2017-12-28   1299.86398  506.424  14.162     520.586     12  2017
# 2017-12-29   1295.08753  584.277  29.854     614.131     12  2017
# 2017-12-30   1215.44897  721.247   7.467     728.714     12  2017
# 2017-12-31   1107.11488  721.176  19.980     741.156     12  2017
#
# [4383 rows x 6 columns]

# %%
Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.
